# %%
side = 5 

perimeter = 4 * side
area = side ** 2

print(perimeter, area)
# Out:
# 20 25

# %%
d = 10  
length = math.pi * d

print(length)
# Out:
# 31.41592653589793

# %%
a = 10
b = 35
c = (a + b)/2

print(c)
# Out:
# 22.5

# %%
sum_ab = a + b
product = a * b
square_a = a ** 2
square_b = b ** 2  

print (sum_ab)
print (product)
print (square_a)
print (square_b)
# Out:
# 45
# 350
# 100
# 1225
